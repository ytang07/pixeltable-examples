# %% [markdown]
# 1. pick some text documents
# 2. pick three embedding models (all three embedding models require less than 1GB of memory, and are small enough to run locally)
# 3. put text and embeddings generated by each model into pixeltable
#
# --- query time ---
#
# 4. create embeddings of text
# 5. get top 3 results from each embedding model
# 6. rank results based on smallest sum of ranking

# %% [markdown]
# # Step 1: Import libraries

# %%
# ! pip install pixeltable tiktoken sentence-transformers

# %%
import pixeltable as pxt
import os
from pixeltable.functions.huggingface import sentence_transformer
import numpy as np

# %% [markdown]
# # Step 2: Define Embedding Functions

# %%
@pxt.expr_udf
def gist_embed(text: str) -> np.ndarray:
    return sentence_transformer(text, model_id='avsolatorio/GIST-Embedding-v0') #768 model from Aivin Solatorio

# %%
@pxt.expr_udf
def bge_base_embed(text: str) -> np.ndarray:
    return sentence_transformer(text, model_id='BAAI/bge-base-en-v1.5') #768 model from BAAI

# %%
@pxt.expr_udf
def e5_embed(text: str) -> np.ndarray:
    return sentence_transformer(text, model_id='intfloat/e5-large-v2')

# %% [markdown]
# # Step 3: Create Directory/Tables

# %%
pxt.drop_dir('reranker_demo', force=True)
pxt.create_dir('reranker_demo')
# Out:
# Created directory `reranker_demo`.

# %%
pxt.drop_table('html_docs')

# %%
html_docs = pxt.create_table('html_docs', {'document': pxt.DocumentType()})
# Out:
# Created table `html_docs`.

# %% [markdown]
# # Step 4: Import Documents

# %%
base_url = "https://en.wikipedia.org/wiki/"

# %%
cities = [
    "Boston",
    "Seattle",
    "San_Francisco",
    "New_York_City"
]

# %%
city_urls = [base_url + cities[x] for x in range(len(cities))]

# %%
city_urls
# Out:
# ['https://en.wikipedia.org/wiki/Boston',
#  'https://en.wikipedia.org/wiki/Seattle',
#  'https://en.wikipedia.org/wiki/San_Francisco',
#  'https://en.wikipedia.org/wiki/New_York_City']

# %%
html_docs.insert(
    {'document': url} for url in city_urls
)
# Out:
# Inserting rows into `html_docs`: 4 rows [00:00, 1846.69 rows/s]
# Inserted 4 rows with 0 errors.
# UpdateStatus(num_rows=4, num_computed_values=0, num_excs=0, updated_cols=[], cols_with_excs=[])

# %% [markdown]
# # Step 5: Chunk Documents

# %%
from pixeltable.iterators import DocumentSplitter
chunked_docs = pxt.create_view(
    "chunked_docs",
    html_docs,
    iterator=DocumentSplitter.create(
        document=html_docs.document,
        separators='paragraph'
    )
)
# Out:
# Inserting rows into `chunked_docs`: 766 rows [00:00, 26178.30 rows/s]
# Created view `chunked_docs` with 766 rows, 0 exceptions.

# %%
chunked_docs.describe()
# Out:
# <style type="text/css">
# #T_49cae th {
#   text-align: center;
# }
# #T_49cae_row0_col0, #T_49cae_row0_col1, #T_49cae_row0_col2, #T_49cae_row1_col0, #T_49cae_row1_col1, #T_49cae_row1_col2, #T_49cae_row2_col0, #T_49cae_row2_col1, #T_49cae_row2_col2 {
#   white-space: pre-wrap;
#   text-align: left;
# }
# </style>
# <table id="T_49cae">
#   <thead>
#     <tr>
#       <th id="T_49cae_level0_col0" class="col_heading level0 col0" >Column Name</th>
#       <th id="T_49cae_level0_col1" class="col_heading level0 col1" >Type</th>
#       <th id="T_49cae_level0_col2" class="col_heading level0 col2" >Computed With</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_49cae_row0_col0" class="data row0 col0" >pos</td>
#       <td id="T_49cae_row0_col1" class="data row0 col1" >Required[Int]</td>
#       <td id="T_49cae_row0_col2" class="data row0 col2" ></td>
#     </tr>
#     <tr>
#       <td id="T_49cae_row1_col0" class="data row1 col0" >text</td>
#       <td id="T_49cae_row1_col1" class="data row1 col1" >Required[String]</td>
#       <td id="T_49cae_row1_col2" class="data row1 col2" ></td>
#     </tr>
#     <tr>
#       <td id="T_49cae_row2_col0" class="data row2 col0" >document</td>
#       <td id="T_49cae_row2_col1" class="data row2 col1" >Required[Document]</td>
#       <td id="T_49cae_row2_col2" class="data row2 col2" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
chunked_docs["e5"] = e5_embed(chunked_docs.text)
# Out:
# Computing cells:   0%|                                                  | 0/766 [00:00<?, ? cells/s]
# Computing cells: 100%|████████████████████████████████████████| 766/766 [02:04<00:00,  6.14 cells/s]
# Added 766 column values with 0 errors.

# %%
chunked_docs["bge_base"] = bge_base_embed(chunked_docs.text)
# Out:
# Computing cells: 100%|████████████████████████████████████████| 766/766 [00:45<00:00, 17.00 cells/s]
# Added 766 column values with 0 errors.

# %%
chunked_docs["gist"] = gist_embed(chunked_docs.text)
# Out:
# Computing cells: 100%|████████████████████████████████████████| 766/766 [00:44<00:00, 17.05 cells/s]
# Added 766 column values with 0 errors.

# %%
chunked_docs.describe()
# Out:
# <style type="text/css">
# #T_bd36e th {
#   text-align: center;
# }
# #T_bd36e_row0_col0, #T_bd36e_row0_col1, #T_bd36e_row0_col2, #T_bd36e_row1_col0, #T_bd36e_row1_col1, #T_bd36e_row1_col2, #T_bd36e_row2_col0, #T_bd36e_row2_col1, #T_bd36e_row2_col2, #T_bd36e_row3_col0, #T_bd36e_row3_col1, #T_bd36e_row3_col2, #T_bd36e_row4_col0, #T_bd36e_row4_col1, #T_bd36e_row4_col2, #T_bd36e_row5_col0, #T_bd36e_row5_col1, #T_bd36e_row5_col2 {
#   white-space: pre-wrap;
#   text-align: left;
# }
# </style>
# <table id="T_bd36e">
#   <thead>
#     <tr>
#       <th id="T_bd36e_level0_col0" class="col_heading level0 col0" >Column Name</th>
#       <th id="T_bd36e_level0_col1" class="col_heading level0 col1" >Type</th>
#       <th id="T_bd36e_level0_col2" class="col_heading level0 col2" >Computed With</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_bd36e_row0_col0" class="data row0 col0" >pos</td>
#       <td id="T_bd36e_row0_col1" class="data row0 col1" >Required[Int]</td>
#       <td id="T_bd36e_row0_col2" class="data row0 col2" ></td>
#     </tr>
#     <tr>
#       <td id="T_bd36e_row1_col0" class="data row1 col0" >text</td>
#       <td id="T_bd36e_row1_col1" class="data row1 col1" >Required[String]</td>
#       <td id="T_bd36e_row1_col2" class="data row1 col2" ></td>
#     </tr>
#     <tr>
#       <td id="T_bd36e_row2_col0" class="data row2 col0" >e5</td>
#       <td id="T_bd36e_row2_col1" class="data row2 col1" >Required[Array[(1024,), Float]]</td>
#       <td id="T_bd36e_row2_col2" class="data row2 col2" >e5_embed(text)</td>
#     </tr>
#     <tr>
#       <td id="T_bd36e_row3_col0" class="data row3 col0" >bge_base</td>
#       <td id="T_bd36e_row3_col1" class="data row3 col1" >Required[Array[(768,), Float]]</td>
#       <td id="T_bd36e_row3_col2" class="data row3 col2" >bge_base_embed(text)</td>
#     </tr>
#     <tr>
#       <td id="T_bd36e_row4_col0" class="data row4 col0" >gist</td>
#       <td id="T_bd36e_row4_col1" class="data row4 col1" >Required[Array[(768,), Float]]</td>
#       <td id="T_bd36e_row4_col2" class="data row4 col2" >gist_embed(text)</td>
#     </tr>
#     <tr>
#       <td id="T_bd36e_row5_col0" class="data row5 col0" >document</td>
#       <td id="T_bd36e_row5_col1" class="data row5 col1" >Required[Document]</td>
#       <td id="T_bd36e_row5_col2" class="data row5 col2" ></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Step 6: Create Embedding Indexes

# %%
chunked_docs.add_embedding_index(col_name="text", idx_name="gist", string_embed=gist_embed)
# Out:
# Computing cells: 100%|████████████████████████████████████████| 766/766 [00:46<00:00, 16.36 cells/s]

# %%
chunked_docs.add_embedding_index(col_name="text", idx_name="bge", string_embed=bge_base_embed)
# Out:
# Computing cells: 100%|████████████████████████████████████████| 766/766 [00:47<00:00, 16.01 cells/s]

# %%
chunked_docs.add_embedding_index(col_name="text", idx_name="e5", string_embed=e5_embed)
# Out:
# Computing cells: 100%|████████████████████████████████████████| 766/766 [02:17<00:00,  5.57 cells/s]

# %% [markdown]
# # Step 7: Get Similarities

# %%
def top_k(query_text: str, idx_name: str):
    sim = chunked_docs.text.similarity(query_text, idx=idx_name)
    return chunked_docs.order_by(sim, asc=False).select(chunked_docs.text, sim=sim).limit(5).collect()

# %%
e5_sims = top_k("Population of Boston", idx_name="e5")
e5_sims
# Out:
#                                                 text       sim
# 0   Boston - Wikipedia Jump to content Search Search  0.853429
# 1  In 1822, [ 16 ] the citizens of Boston voted t...  0.847979
# 2  Boston ( US : / ˈ b ɔː s t ə n / ⓘ [ 9 ] ) is ...  0.839760
# 3  State capital in New England, United States Bo...  0.837083
# 4  In 2020, Boston was estimated to have 691,531 ...  0.833195

# %%
gist_sims = top_k("Population of Boston", idx_name="gist")
gist_sims
# Out:
#                                                 text       sim
# 0  In 2020, Boston was estimated to have 691,531 ...  0.879435
# 1  Boston ( US : / ˈ b ɔː s t ə n / ⓘ [ 9 ] ) is ...  0.874415
# 2  Demographics [ edit ] See also: History of the...  0.848949
# 3  In 1822, [ 16 ] the citizens of Boston voted t...  0.816145
# 4  Environment [ edit ] Population density and el...  0.812413

# %%
bge_sims = top_k("Population of Boston", idx_name="bge")
bge_sims
# Out:
#                                                 text       sim
# 0  In 2020, Boston was estimated to have 691,531 ...  0.789566
# 1  Boston ( US : / ˈ b ɔː s t ə n / ⓘ [ 9 ] ) is ...  0.769459
# 2  Demographics [ edit ] See also: History of the...  0.744878
# 3  The Boston metro area contained a Jewish popul...  0.731926
# 4  In 1822, [ 16 ] the citizens of Boston voted t...  0.727893

# %% [markdown]
# # Step 8: Rerank

# %%
reranking_dict = {}

# %%
for index, text in enumerate(bge_sims["text"]):
    if text not in reranking_dict:
        reranking_dict[text] = bge_sims["sim"][index]
    elif text in reranking_dict:
        reranking_dict[text] += bge_sims["sim"][index]

# %%
for index, text in enumerate(e5_sims["text"]):
    if text not in reranking_dict:
        reranking_dict[text] = bge_sims["sim"][index]
    elif text in reranking_dict:
        reranking_dict[text] += bge_sims["sim"][index]

# %%
for index, text in enumerate(gist_sims["text"]):
    if text not in reranking_dict:
        reranking_dict[text] = bge_sims["sim"][index]
    elif text in reranking_dict:
        reranking_dict[text] += bge_sims["sim"][index]

# %%
reranking_dict
# Out:
# {"In 2020, Boston was estimated to have 691,531 residents living in 266,724 households [ 4 ] —a 12% population increase over 2010. The city is the third-most densely populated large U.S. city of over half a million residents, and the most densely populated state capital. Some 1.2\xa0million persons may be within Boston's boundaries during work hours, and as many as 2\xa0million during special events. This fluctuation of people is caused by hundreds of thousands of suburban residents who travel to the city for work, education, health care, and special events. [ 162 ]": 2.307025416367836,
#  'Boston ( US : / ˈ b ɔː s t ə n / ⓘ [ 9 ] ) is the capital and most populous city in the Commonwealth of Massachusetts in the United States . The city serves as the cultural and financial center of the New England region of the Northeastern United States . It has an area of 48.4\xa0sq\xa0mi (125\xa0km 2 ) [ 10 ] and a population of 675,647 as of the 2020 census , making it the third-largest city in the Northeast after New York City and Philadelphia . [ 4 ] The larger Greater Boston metropolitan statistical area , which includes and surrounds the city, has a population of 4,919,179 as of 2023, making it the largest in New England and eleventh-largest in the country. [ 11 ] [ 12 ] [ 13 ]': 2.2837965213607783,
#  'Demographics [ edit ] See also: History of the Irish in Boston , History of Italian Americans in Boston , History of African Americans in Boston , Chinese Americans in Boston , Dominican-Americans in Boston , Vietnamese in Boston , and LGBT culture in Boston Historical population Year Pop. ±% 1680 4,500 — 1690 7,000 +55.6% 1700 6,700 −4.3% 1710 9,000 +34.3% 1722 10,567 +17.4% 1742 16,382 +55.0% 1765 15,520 −5.3% 1790 18,320 +18.0% 1800 24,937 +36.1% 1810 33,787 +35.5% 1820 43,298 +28.1% 1830 61,392 +41.8% 1840 93,383 +52.1% 1850 136,881 +46.6% 1860 177,840 +29.9% 1870 250,526 +40.9% 1880 362,839 +44.8% 1890 448,477 +23.6% 1900 560,892 +25.1% 1910 670,585 +19.6% 1920 748,060 +11.6% 1930 781,188 +4.4% 1940 770,816 −1.3% 1950 801,444 +4.0% 1960 697,197 −13.0% 1970 641,071 −8.1% 1980 562,994 −12.2% 1990 574,283 +2.0% 2000 589,141 +2.6% 2010 617,594 +4.8% 2020 675,647 +9.4% 2022* 650,706 −3.7% *=population estimate. Source: United States census records and Population Estimates Program data. [ 148 ] [ 149 ] [ 150 ] [ 151 ] [ 152 ] [ 153 ] [ 154 ] [ 155 ] [ 156 ] [ 157 ] [ 158 ] [ 159 ] [ 160 ] 2010–2020 [ 4 ] Source: U.S. Decennial Census [ 161 ] Packed circles diagram showing estimates of the ethnic origins of people in Boston in 2021': 1.4897563457489014,
#  'The Boston metro area contained a Jewish population of approximately 248,000 as of 2015. [ 186 ] More than half the Jewish households in the Greater Boston area reside in the city itself, Brookline , Newton , Cambridge , Somerville , or adjacent towns. [ 186 ] A small minority practices Confucianism , and some practice Boston Confucianism , an American evolution of Confucianism adapted for Boston intellectuals. [ 187 ]': 0.731926441192627,
#  'In 1822, [ 16 ] the citizens of Boston voted to change the official name from the "Town of Boston" to the "City of Boston", and on March 19, 1822, the people of Boston accepted the charter incorporating the city. [ 69 ] At the time Boston was chartered as a city, the population was about 46,226, while the area of the city was only 4.8\xa0sq\xa0mi (12\xa0km 2 ). [ 69 ]': 2.2292787133069227,
#  'Boston - Wikipedia Jump to content Search Search': 0.789566159248352,
#  "State capital in New England, United States Boston State capital Downtown from Boston Harbor Acorn Street on Beacon Hill Old State House Massachusetts State House Fenway Park during a Boston Red Sox game Back Bay from the Charles River Flag Seal Coat of arms Wordmark Nickname(s): Bean Town, Title Town, others Motto(s): Sicut patribus sit Deus nobis ( Latin ) 'As God was with our fathers, so may He be with us' Show Boston Show Suffolk County Show Massachusetts Show the United States Boston Show map of Greater Boston area Boston Show map of Massachusetts Boston Show map of the United States Boston Show map of Earth Coordinates: 42°21′37″N 71°3′28″W  /  42.36028°N 71.05778°W  / 42.36028; -71.05778 Country United States Region New England State Massachusetts County Suffolk [ 1 ] Historic countries Kingdom of England Commonwealth of England Kingdom of Great Britain Historic colonies Massachusetts Bay Colony , Dominion of New England , Province of Massachusetts Bay Settled 1625 Incorporated (town) September 7, 1630 (date of naming, Old Style ) September 17, 1630 (date of naming, New Style ) Incorporated\xa0(city) March 19, 1822 Named for Boston, Lincolnshire Government •\xa0Type Strong mayor / Council • Mayor Michelle Wu ( D ) • Council Boston City Council • Council President Ruthzee Louijeune (D) Area [ 2 ] • State capital 89.61\xa0sq\xa0mi (232.10\xa0km 2 ) •\xa0Land 48.34\xa0sq\xa0mi (125.20\xa0km 2 ) •\xa0Water 41.27\xa0sq\xa0mi (106.90\xa0km 2 ) •\xa0Urban 1,655.9\xa0sq\xa0mi (4,288.7\xa0km 2 ) •\xa0Metro 4,500\xa0sq\xa0mi (11,700\xa0km 2 ) • CSA 10,600\xa0sq\xa0mi (27,600\xa0km 2 ) Elevation [ 3 ] 46\xa0ft (14\xa0m) Population ( 2020 ) [ 4 ] • State capital 675,647 •\xa0Estimate (2021) [ 4 ] 654,776 •\xa0Rank 66th in North America 25th in the United States 1st in Massachusetts •\xa0Density 13,976.98/sq\xa0mi (5,396.51/km 2 ) • Urban [ 5 ] 4,382,009 (US: 10th ) •\xa0Urban\xa0density 2,646.3/sq\xa0mi (1,021.8/km 2 ) • Metro [ 6 ] 4,941,632 (US: 10th ) Demonym Bostonian GDP [ 7 ] •\xa0Boston (MSA) $571.6 billion (2022) Time zone UTC−5 ( EST ) •\xa0Summer ( DST ) UTC−4 ( EDT ) ZIP Codes 53 ZIP Codes [ 8 ] 02108–02137, 02163, 02196, 02199, 02201, 02203–02206, 02210–02212, 02215, 02217, 02222, 02126, 02228, 02241, 02266, 02283–02284, 02293, 02295, 02297–02298, 02467 (also includes parts of Newton and Brookline) Area codes 617 and 857 FIPS code 25-07000 GNIS feature ID 617565 Website boston .gov": 0.731926441192627,
#  'Environment [ edit ] Population density and elevation above sea level in Greater Boston as of 2010': 0.7278930978711319}

# %%
reranked = [(text, total_sim) for text, total_sim in reranking_dict.items()]
reranked.sort()
print(reranked[0])
# Out:
# ('Boston ( US : / ˈ b ɔː s t ə n / ⓘ [ 9 ] ) is the capital and most populous city in the Commonwealth of Massachusetts in the United States . The city serves as the cultural and financial center of the New England region of the Northeastern United States . It has an area of 48.4\xa0sq\xa0mi (125\xa0km 2 ) [ 10 ] and a population of 675,647 as of the 2020 census , making it the third-largest city in the Northeast after New York City and Philadelphia . [ 4 ] The larger Greater Boston metropolitan statistical area , which includes and surrounds the city, has a population of 4,919,179 as of 2023, making it the largest in New England and eleventh-largest in the country. [ 11 ] [ 12 ] [ 13 ]', 2.2837965213607783)

# %%
pxt.drop_table('documents')

# %%
# docs = pxt.create_table('documents', {'document': pxt.DocumentType(nullable=True),
#                                       'document_name': pxt.StringType(nullable=True)})

docs = pxt.create_table('documents', {'document': pxt.DocumentType()})
# Out:
# Created table `documents`.

# %%
docs.describe()
# Out:
# <style type="text/css">
# #T_d0ea8 th {
#   text-align: center;
# }
# #T_d0ea8_row0_col0, #T_d0ea8_row0_col1, #T_d0ea8_row0_col2 {
#   white-space: pre-wrap;
#   text-align: left;
# }
# </style>
# <table id="T_d0ea8">
#   <thead>
#     <tr>
#       <th id="T_d0ea8_level0_col0" class="col_heading level0 col0" >Column Name</th>
#       <th id="T_d0ea8_level0_col1" class="col_heading level0 col1" >Type</th>
#       <th id="T_d0ea8_level0_col2" class="col_heading level0 col2" >Computed With</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d0ea8_row0_col0" class="data row0 col0" >document</td>
#       <td id="T_d0ea8_row0_col1" class="data row0 col1" >Required[Document]</td>
#       <td id="T_d0ea8_row0_col2" class="data row0 col2" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
ten_ks = os.listdir("./10k")
ten_ks
# Out:
# ['uber_2021.pdf', 'lyft_2021.pdf']

# %%
for doc in ten_ks:
    docs.insert(
        document=f"./10k/{doc}"
    )
# Out:
# Inserting rows into `documents`: 1 rows [00:00, 706.59 rows/s]
# Inserted 1 row with 0 errors.
# Inserting rows into `documents`: 1 rows [00:00, 846.65 rows/s]
# Inserted 1 row with 0 errors.

# %%
docs.describe()
# Out:
# <style type="text/css">
# #T_253ea th {
#   text-align: center;
# }
# #T_253ea_row0_col0, #T_253ea_row0_col1, #T_253ea_row0_col2 {
#   white-space: pre-wrap;
#   text-align: left;
# }
# </style>
# <table id="T_253ea">
#   <thead>
#     <tr>
#       <th id="T_253ea_level0_col0" class="col_heading level0 col0" >Column Name</th>
#       <th id="T_253ea_level0_col1" class="col_heading level0 col1" >Type</th>
#       <th id="T_253ea_level0_col2" class="col_heading level0 col2" >Computed With</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_253ea_row0_col0" class="data row0 col0" >document</td>
#       <td id="T_253ea_row0_col1" class="data row0 col1" >String</td>
#       <td id="T_253ea_row0_col2" class="data row0 col2" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
from pixeltable.iterators import DocumentSplitter
chunked_docs = pxt.create_view(
    "chunked_docs",
    docs,
    iterator=DocumentSplitter.create(
        document=docs.document,
        separators='token_limit',
        limit=300
    )
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[64], line 2
#       1 from pixeltable.iterators import DocumentSplitter
# ----> 2 chunked_docs = pxt.create_view(
#       3     "chunked_docs",
#       4     docs,
#       5     iterator=DocumentSplitter.create(
#       6         document=docs.document,
#       7         separators='token_limit',
#       8         limit=300
#       9     )
#      10 )
#
# File ~/Documents/workspace/pixel_table_test/ptt/lib/python3.12/site-packages/pixeltable/globals.py:179, in create_view(path_str, base, additional_columns, is_snapshot, iterator, num_retained_versions, comment, ignore_errors)
#     176 else:
#     177     iterator_class, iterator_args = iterator
# --> 179 view = catalog.View._create(
#     180     dir._id,
#     181     path.name,
#     182     base=tbl_version_path,
#     183     additional_columns=additional_columns,
#     184     predicate=where,
#     185     is_snapshot=is_snapshot,
#     186     iterator_cls=iterator_class,
#     187     iterator_args=iterator_args,
#     188     num_retained_versions=num_retained_versions,
#     189     comment=comment,
#     190 )
#     191 Catalog.get().paths[path] = view
#     192 _logger.info(f'Created view `{path_str}`.')
#
# File ~/Documents/workspace/pixel_table_test/ptt/lib/python3.12/site-packages/pixeltable/catalog/view.py:158, in View._create(cls, dir_id, name, base, additional_columns, predicate, is_snapshot, num_retained_versions, comment, iterator_cls, iterator_args)
#     156     from pixeltable.plan import Planner
#     157     plan, num_values_per_row = Planner.create_view_load_plan(view._tbl_version_path)
# --> 158     num_rows, num_excs, cols_with_excs = tbl_version.store_tbl.insert_rows(
#     159         plan, session.connection(), v_min=tbl_version.version)
#     160     print(f'Created view `{name}` with {num_rows} rows, {num_excs} exceptions.')
#     162 session.commit()
#
# File ~/Documents/workspace/pixel_table_test/ptt/lib/python3.12/site-packages/pixeltable/store.py:323, in StoreBase.insert_rows(self, exec_plan, conn, v_min, show_progress, rowids)
#     321 try:
#     322     exec_plan.open()
# --> 323     for row_batch in exec_plan:
#     324         num_rows += len(row_batch)
#     325         for batch_start_idx in range(0, len(row_batch), self.__INSERT_BATCH_SIZE):
#     326             # compute batch of rows and convert them into table rows
#
# File ~/Documents/workspace/pixel_table_test/ptt/lib/python3.12/site-packages/pixeltable/exec/expr_eval_node.py:45, in ExprEvalNode.__next__(self)
#      44 def __next__(self) -> DataRowBatch:
# ---> 45     input_batch = next(self.input)
#      46     # compute target exprs
#      47     for cohort in self.cohorts:
#
# File ~/Documents/workspace/pixel_table_test/ptt/lib/python3.12/site-packages/pixeltable/exec/component_iteration_node.py:100, in ComponentIterationNode.__next__(self)
#      98 if self.__output is None:
#      99     self.__output = self.__output_batches()
# --> 100 return next(self.__output)
#
# File ~/Documents/workspace/pixel_table_test/ptt/lib/python3.12/site-packages/pixeltable/exec/component_iteration_node.py:53, in ComponentIterationNode.__output_batches(self)
#      49 # We need to ensure that all of the required (non-nullable) parameters of the iterator are
#      50 # specified and are not null. If any of them are null, then we skip this row (i.e., we emit 0
#      51 # output rows for this input row).
#      52 if self.__non_nullable_args_specified(iterator_args):
# ---> 53     iterator = self.view.iterator_cls(**iterator_args)
#      54     for pos, component_dict in enumerate(iterator):
#      55         output_row = output_batch.add_row()
#
# File ~/Documents/workspace/pixel_table_test/ptt/lib/python3.12/site-packages/pixeltable/iterators/document.py:124, in DocumentSplitter.__init__(self, document, separators, limit, overlap, metadata, html_skip_tags, tiktoken_encoding, tiktoken_target_model)
#     122 if html_skip_tags is None:
#     123     html_skip_tags = ['nav']
# --> 124 self._doc_handle = get_document_handle(document)
#     125 assert self._doc_handle is not None
#     126 # calling the output_schema method to validate the input arguments
#
# File ~/Documents/workspace/pixel_table_test/ptt/lib/python3.12/site-packages/pixeltable/utils/documents.py:21, in get_document_handle(path)
#      20 def get_document_handle(path: str) -> Optional[DocumentHandle]:
# ---> 21     doc_format = puremagic.from_file(path)
#      23     if doc_format == '.pdf':
#      24         pdf_doc = get_pdf_handle(path)
#
# File ~/Documents/workspace/pixel_table_test/ptt/lib/python3.12/site-packages/puremagic/main.py:270, in from_file(filename, mime)
#     260 def from_file(filename: os.PathLike | str, mime: bool = False) -> str:
#     261     """Opens file, attempts to identify content based
#     262     off magic number and will return the file extension.
#     263     If mime is True it will return the mime type instead.
#    (...)
#     267     :return: guessed extension or mime
#     268     """
# --> 270     head, foot = _file_details(filename)
#     271     return _magic(head, foot, mime, ext_from_filename(filename))
#
# File ~/Documents/workspace/pixel_table_test/ptt/lib/python3.12/site-packages/puremagic/main.py:211, in _file_details(filename)
#     209 def _file_details(filename: os.PathLike | str) -> tuple[bytes, bytes]:
#     210     """Grab the start and end of the file"""
# --> 211     with open(filename, "rb") as fin:
#     212         head = fin.read(max_head)
#     213         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/10k/uber_2021.pdf'

# %%
chunked_docs.drop_column("jxm_cde_small_v1")

# %%
chunked_docs["jxm_cde_small_v1"] = jxm_cde_small_v1_embed(chunked_docs.text)
# Out:
# Computing cells:   0%|                                                  | 0/766 [00:00<?, ? cells/s]
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Documents/workspace/pixel_table_test/ptt/lib/python3.12/site-packages/sentence_transformers/util.py:1124, in import_from_string(dotted_path)
#    1123 try:
# -> 1124     module = importlib.import_module(dotted_path)
#    1125 except Exception:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1310, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'sentence_transformers_impl'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 chunked_docs["jxm_cde_small_v1"] = jxm_cde_small_v1_embed(chunked_docs.text)
#
# File ~/Documents/workspace/pixel_table_test/ptt/lib/python3.12/site-packages/pixeltable/catalog/table.py:326, in Table.__setitem__(self, col_name, spec)
#     324 if not isinstance(spec, (ts.ColumnType, exprs.Expr, type, _GenericAlias)):
#     325     raise excs.Error(f'Column spec must be a ColumnType, Expr, or type, got {type(spec)}')
# --> 326 self.add_column(type=None, stored=None, print_stats=False, on_error='abort', **{col_name: spec})
#
# File ~/Documents/workspace/pixel_table_test/ptt/lib/python3.12/site-packages/pixeltable/catalog/table.py:413, in Table.add_column(self, type, stored, print_stats, on_error, **kwargs)
#     411 new_col = self._create_columns({col_name: col_schema})[0]
#     412 self._verify_column(new_col, set(self._schema.keys()), set(self._query_names))
# --> 413 status = self._tbl_version.add_column(new_col, print_stats=print_stats, on_error=on_error)
#     414 FileCache.get().emit_eviction_warnings()
#     415 return status
#
# File ~/Documents/workspace/pixel_table_test/ptt/lib/python3.12/site-packages/pixeltable/catalog/table_version.py:503, in TableVersion.add_column(self, col, print_stats, on_error)
#     501 self.schema_version = self.version
#     502 with Env.get().engine.begin() as conn:
# --> 503     status = self._add_columns([col], conn, print_stats=print_stats, on_error=on_error)
#     504     _ = self._add_default_index(col, conn)
#     505     self._update_md(time.time(), conn, preceding_schema_version=preceding_schema_version)
#
# File ~/Documents/workspace/pixel_table_test/ptt/lib/python3.12/site-packages/pixeltable/catalog/table_version.py:561, in TableVersion._add_columns(self, cols, conn, print_stats, on_error)
#     559 plan.open()
#     560 try:
# --> 561     num_excs = self.store_tbl.load_column(col, plan, value_expr_slot_idx, conn, on_error)
#     562 except sql.exc.DBAPIError as exc:
#     563     # Wrap the DBAPIError in an excs.Error to unify processing in the subsequent except block
#     564     raise excs.Error(f'SQL error during execution of computed column `{col.name}`:\n{exc}') from exc
#
# File ~/Documents/workspace/pixel_table_test/ptt/lib/python3.12/site-packages/pixeltable/store.py:252, in StoreBase.load_column(self, col, exec_plan, value_expr_slot_idx, conn, on_error)
#     248 tmp_tbl.create(bind=conn)
#     250 try:
#     251     # insert rows from exec_plan into temp table
# --> 252     for row_batch in exec_plan:
#     253         num_rows += len(row_batch)
#     254         tbl_rows: list[dict[str, Any]] = []
#
# File ~/Documents/workspace/pixel_table_test/ptt/lib/python3.12/site-packages/pixeltable/exec/expr_eval_node.py:48, in ExprEvalNode.__next__(self)
#      46 # compute target exprs
#      47 for cohort in self.cohorts:
# ---> 48     self._exec_cohort(cohort, input_batch)
#      49 _logger.debug(f'ExprEvalNode: returning {len(input_batch)} rows')
#      50 return input_batch
#
# File ~/Documents/workspace/pixel_table_test/ptt/lib/python3.12/site-packages/pixeltable/exec/expr_eval_node.py:204, in ExprEvalNode._exec_cohort(self, cohort, rows)
#     199 call_kwargs = {
#     200     k: kwarg_batches[k][ext_batch_offset:ext_batch_offset + num_ext_batch_rows]
#     201     for k in kwarg_batches.keys()
#     202 }
#     203 start_ts = time.perf_counter()
# --> 204 result_batch = fn_call.fn.exec_batch(*call_args, **call_kwargs)
#     205 self.ctx.profile.eval_time[fn_call.slot_idx] += time.perf_counter() - start_ts
#     206 self.ctx.profile.eval_count[fn_call.slot_idx] += num_ext_batch_rows
#
# File ~/Documents/workspace/pixel_table_test/ptt/lib/python3.12/site-packages/pixeltable/func/callable_function.py:66, in CallableFunction.exec_batch(self, *args, **kwargs)
#      64 constant_kwargs = {k: v[0] for k, v in kwargs.items() if k in constant_param_names}
#      65 batched_kwargs = {k: v for k, v in kwargs.items() if k not in constant_param_names}
# ---> 66 return self.py_fn(*args, **constant_kwargs, **batched_kwargs)
#
# File ~/Documents/workspace/pixel_table_test/ptt/lib/python3.12/site-packages/pixeltable/functions/huggingface.py:53, in sentence_transformer(sentence, model_id, normalize_embeddings)
#      50 env.Env.get().require_package('sentence_transformers')
#      51 from sentence_transformers import SentenceTransformer  # type: ignore
# ---> 53 model = _lookup_model(model_id, SentenceTransformer)
#      55 array = model.encode(sentence, normalize_embeddings=normalize_embeddings)
#      56 return [array[i] for i in range(array.shape[0])]
#
# File ~/Documents/workspace/pixel_table_test/ptt/lib/python3.12/site-packages/pixeltable/functions/huggingface.py:394, in _lookup_model(model_id, create, device)
#     392 key = (model_id, create, device)  # For safety, include the `create` callable in the cache key
#     393 if key not in _model_cache:
# --> 394     model = create(model_id)
#     395     if isinstance(model, nn.Module):
#     396         if device is not None:
#
# File ~/Documents/workspace/pixel_table_test/ptt/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py:306, in SentenceTransformer.__init__(self, model_name_or_path, modules, device, prompts, default_prompt_name, similarity_fn_name, cache_folder, trust_remote_code, revision, local_files_only, token, use_auth_token, truncate_dim, model_kwargs, tokenizer_kwargs, config_kwargs, model_card_data, backend)
#     297         model_name_or_path = __MODEL_HUB_ORGANIZATION__ + "/" + model_name_or_path
#     299 if is_sentence_transformer_model(
#     300     model_name_or_path,
#     301     token,
#    (...)
#     304     local_files_only=local_files_only,
#     305 ):
# --> 306     modules, self.module_kwargs = self._load_sbert_model(
#     307         model_name_or_path,
#     308         token=token,
#     309         cache_folder=cache_folder,
#     310         revision=revision,
#     311         trust_remote_code=trust_remote_code,
#     312         local_files_only=local_files_only,
#     313         model_kwargs=model_kwargs,
#     314         tokenizer_kwargs=tokenizer_kwargs,
#     315         config_kwargs=config_kwargs,
#     316     )
#     317 else:
#     318     modules = self._load_auto_model(
#     319         model_name_or_path,
#     320         token=token,
#    (...)
#     327         config_kwargs=config_kwargs,
#     328     )
#
# File ~/Documents/workspace/pixel_table_test/ptt/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py:1655, in SentenceTransformer._load_sbert_model(self, model_name_or_path, token, cache_folder, revision, trust_remote_code, local_files_only, model_kwargs, tokenizer_kwargs, config_kwargs)
#    1653 for module_config in modules_config:
#    1654     class_ref = module_config["type"]
# -> 1655     module_class = self._load_module_class_from_ref(
#    1656         class_ref, model_name_or_path, trust_remote_code, revision, model_kwargs
#    1657     )
#    1659     # For Transformer, don't load the full directory, rely on `transformers` instead
#    1660     # But, do load the config file first.
#    1661     if module_config["path"] == "":
#
# File ~/Documents/workspace/pixel_table_test/ptt/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py:1560, in SentenceTransformer._load_module_class_from_ref(self, class_ref, model_name_or_path, trust_remote_code, revision, model_kwargs)
#    1556     except OSError:
#    1557         # Ignore the error if the file does not exist, and fall back to the default import
#    1558         pass
# -> 1560 return import_from_string(class_ref)
#
# File ~/Documents/workspace/pixel_table_test/ptt/lib/python3.12/site-packages/sentence_transformers/util.py:1126, in import_from_string(dotted_path)
#    1124     module = importlib.import_module(dotted_path)
#    1125 except Exception:
# -> 1126     module = importlib.import_module(module_path)
#    1128 try:
#    1129     return getattr(module, class_name)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'sentence_transformers_impl'

# %%
@pxt.expr_udf
def jxm_cde_small_v1_embed(text: str) -> np.ndarray:
    return sentence_transformer(text, model_id='jxm/cde-small-v1') #768 model from Jack Morris
